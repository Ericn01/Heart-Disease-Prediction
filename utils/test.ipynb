# %%
FILES = ['cleveland.data', 'hungarian.data', 'switzerland.data', 'va.data']
DIRECTORY = '../data'
DATASET_NAMES = ['Cleveland', 'Hungarian', 'Switzerland', 'VA Long Beach']
COLUMN_NAMES = ["Age", "Sex", "Chest Pain", "Rest BP", "Chol", "FBS", 
                "Rest ECG", "Max HR", "Ex Angina", "Oldpeak", "Slope", 
                "Ca", "Thal", "CVD Class"]

from data_loading import load_datasets, create_file_path, modify_datataset

filepaths = [create_file_path(f, DIRECTORY) for f in FILES]
    
# Load datasets
dfs = load_datasets(filepaths)

for df in dfs:
    modify_datataset(df, column_names=COLUMN_NAMES)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 297    False
# 298    False
# 299    False
# 300    False
# 301    False
# Name: Age, Length: 302, dtype: bool
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 297    False
# 298    False
# 299    False
# 300    False
# 301    False
# Name: Rest BP, Length: 302, dtype: bool
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 297    False
# 298    False
# 299    False
# 300    False
# 301    False
# Name: Chol, Length: 302, dtype: bool
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 297    False
# 298    False
# 299    False
# 300    False
# 301    False
# Name: Max HR, Length: 302, dtype: bool
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 297    False
# 298    False
# 299    False
# 300    False
# 301    False
# ...
