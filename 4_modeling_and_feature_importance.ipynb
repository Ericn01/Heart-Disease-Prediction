# %% [markdown]
# # UCI Heart Disease Dataset: Predictive Modeling & Feature Importance
#
# ## Context
# Based on the exploratory analysis in Notebook 3, we identified [...]. This notebook develops predictive models to classify heart disease severity and, most importantly, identifies the most important factors driving these predictions.
#
# ## Objective
# Build a robust predictive model for heart disease severity and extract interpretable feature importance to answer: **What are the most important factors in determining heart disease severity?**
#
# ## Research Questions
# 1. Which modeling approach best predicts heart disease severity?
# 2. What are the most important features for prediction?
# 3. How do feature importance rankings align with medical knowledge?
# 4. What is the model's performance and reliability?
# 5. What are the clinical and practical implications of our findings?
#
# ## Notebook Outline
# 1. Problem Framing & Approach
# 2. Data Preparation for Modeling
# 3. Baseline Models & Comparison
# 4. Model Development & Tuning
# 5. Model Evaluation
# 6. Feature Importance Analysis
# 7. Interpretation & Validation
# 8. Conclusions & Recommendations
